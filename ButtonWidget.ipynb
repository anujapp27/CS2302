# %% [markdown]
# # Button Widget
# * Button is another standard widget in python tkinter lib
# * With button you can interact with the program
# * The font of text in LABEL can be displayed in diffrent fonts but in button that cannot be done.
# * In button you can incorporate text as well as Image

# %%
from tkinter import *
## need to use specific time functions - strftime and localtime
from time import *

def clicked():
    'prints day and time info'
    time = strftime('Day:  %d %b %Y\nTime: %H:%M:%S %p\n',
                    localtime())
    print(time)

root = Tk()

# Option command specifies the function that is executed every time the button is clicked.
button = Button(root,
                text='Click it',   
                command=clicked)
button.pack()
root.mainloop()
# Out:
# Day:  30 Mar 2020
# Time: 13:11:29 PM

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Once we **click the button**, we get to see the Day and Time on our screens or the output console.
# Please Note the Day and Time is not shown in the window or a new window but on the console!

# %% [markdown]
# Now, if we want the out put to show in a new window we need to execute the following piece of code:

# %%
from tkinter import *
from time import *
from tkinter.messagebox import showinfo

def clicked():
    #'prints day and time info'
    time = strftime('Day:  %d %b %Y\nTime: %H:%M:%S %p\n',
                    localtime())
    showinfo(message = time)

root = Tk()
button = Button(root,
                text='Click it',   
                command=clicked)
button.pack()
root.mainloop()

# %% [markdown]
# ![image.png](attachment:image.png)
